# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats

# %% [raw]
# a. Check whether the MPG of Cars follows Normal Distribution

# %%
data = pd.read_csv(r"C:\Users\Dell\Downloads\Assignment 1\Cars.csv")
data.head(2)
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833

# %%
# importing warning libraries
import warnings
warnings.filterwarnings('ignore')

sns.distplot(data.MPG, label= 'Car-MPG')
plt.legend()
plt.show()

# %%
data['MPG'].mean()
# Out:
# 34.422075728024666

# %%
data['MPG'].median()
# Out:
# 35.15272697

# %%
plt.boxplot(data.MPG)
plt.grid()
plt.show()

# %%
stats.probplot(data['MPG'], dist="norm", plot=plt)
plt.show()

# %% [raw]
# MPG of car follows normal distribution.

# %% [raw]
# b.  Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist) from wc-at data set follows Normal Distribution

# %%
df = pd.read_csv(r"C:\Users\Dell\Downloads\Assignment 1\wc-at.csv")
df.head(2)
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89

# %%
fig, ax= plt.subplots(figsize = (10,4))

plt.subplot(1,2,1)
plt.boxplot(df.Waist)
plt.title('Waist')

plt.subplot(1,2,2)
plt.boxplot(df.AT)
plt.title('AT')

plt.show()

# %%
sns.distplot(df['AT'])
plt.show()

# %%
sns.distplot(df['Waist'])
plt.show()

# %%
df.mean(), df.median()
# Out:
# (Waist     91.901835
#  AT       101.894037
#  dtype: float64,
#  Waist    90.80
#  AT       96.54
#  dtype: float64)

# %%
stats.probplot(df['Waist'], plot=plt, dist='norm')
plt.show()

# %%
stats.probplot(df['AT'], plot=plt, dist='norm')
plt.show()

# %% [raw]
# Adipose Tissue (AT) and Waist does not follow Normal Distribution.
